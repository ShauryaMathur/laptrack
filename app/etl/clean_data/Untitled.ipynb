# %%
import pandas as pd

# Display all rows
pd.set_option('display.max_rows', None)

# Display all columns
pd.set_option('display.max_columns', None)

# Increase the display width to show full text
pd.set_option('display.max_colwidth', None)

df = pd.read_csv('./Laptrack_1.csv')
df.shape
# Out:
# (4551, 23)

# %%
df.columns
# Out:
# Index(['brand', 'laptop_model_name', 'laptop_model_number', 'processor_brand',
#        'processor_model', 'storage_type', 'operating_system',
#        'display_resolution', 'extracted_rating', 'battery_life_hours_upto',
#        'price', 'stock', 'time_of_extraction', 'url', 'source',
#        'storage_capacity_gb', 'display_size_inches', 'ram_gb', 'no_of_reviews',
#        'laptop_dimensions', 'laptop_weight_pounds', 'image_src', 'title'],
#       dtype='object')

# %%
sorted(map(str, df['brand'].unique()))
# Out:
# ['ACEMAGIC',
#  'ANPCOWER',
#  'ASUS',
#  'AXL',
#  'Acer',
#  'AimCare',
#  'Akocrsiy',
#  'Alienware',
#  'ApoloSign',
#  'Apple',
#  'Avita',
#  'BiTECOOL',
#  'CHUWI',
#  'Colorful',
#  'Coolby',
#  'Dell',
#  'ECOHERO',
#  'FUNYET',
#  'GIGABYTE',
#  'Gateway',
#  'Getac',
#  'Gina Joyfurno',
#  'HP',
#  'IJKKJI',
#  'INHONLAP',
#  'Infinix',
#  'KAIGERR',
#  'KOOFORWAY',
#  'LETSUNG',
#  'LG',
#  'Lapbook',
#  'Lenovo',
#  'MSI',
#  'Maxsignage',
#  'Microsoft',
#  'Molegar',
#  'NIAKUN',
#  'Naclud',
#  'Nmybwo',
#  'Oemgenuine',
#  'Panasonic',
#  'Primebook',
#  'Razer',
#  'SAINTDISE',
#  'SAIWAN',
#  'SAMSUNG',
#  'SGIN',
#  'THKGRCE',
#  'TPV',
#  'Thomson',
#  'ULTIMUS',
#  'VGKE',
#  'Vaio',
#  'WINGS',
#  'WIPEMIK',
#  'ZEBRONICS',
#  'ZENAERO',
#  'ZHAOHUIXIN',
#  'Zuleisy',
#  'ist computers',
#  'jumper',
#  'nan',
#  'realme',
#  'walker']

# %% [markdown]
# # SPACY NER

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_lg')
nlp

# %%
doc = nlp('Donal Trump was the President of USA')
doc
# Out:
# Donal Trump was the President of USA

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
doc.ents
# Out:
# (Donal Trump, USA)

# %%
doc.ents[0],type(doc.ents[0])
# Out:
# (Donal Trump, spacy.tokens.span.Span)

# %%
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donal Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was the President of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>

# %%
df.head(1)['title']
# Out:
# 0    TPV 15.6" Laptop Computer (Intel Core i5 / 16GB RAM/ 512GB SSD), MS Office 2024, FHD Display with 100% sRGB Color Gamut, Windows 11 Pro Notebook PC with Dual Band Wi-Fi, Webcam (Silver)
# Name: title, dtype: object

# %%
displacy.render(nlp(df.iloc[10]['title']),style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Laptop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Intel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Celeron N4020,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 GB RAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     64 GB Storage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14-inch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  Micro-edge HD Display, Windows 11 Home,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thin &amp; Portable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     K Graphics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One Year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  365 (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -dq0040nr,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Snowflake White
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# )</div></span>

# %%
df['brand'].isna().sum()
# Out:
# np.int64(1)

# %%
title = df[df['brand'].isna()]['url']
title
# Out:
# 3553    https://www.bestbuy.com/site/15-6-full-hd-touch-screen-laptop-intel-core-i7-16gb-memory-512gb-ssd-natural-silver/6587202.p?skuId=6587202
# Name: url, dtype: object

# %%
df[df['source'] == 'Amazon'].head()['laptop_model_number']
# Out:
# 0    AceBook_Silver
# 1           660 G11
# 2                HP
# 3        82R400EMUS
# 4       G614JV-AS74
# Name: laptop_model_number, dtype: object

# %%
import pandas as pd
from collections import defaultdict


# Step 1: Clean the column
df=df.copy()
df['laptop_model_number_temp'] = df['laptop_model_number'].fillna('').str.strip().str.lower()

# Step 2: Check for substrings and group
groups = defaultdict(list)  # To store groups of indices
visited = set()  # Keep track of visited rows

for i, model_i in enumerate(df['laptop_model_number_temp']):
    if i in visited:
        continue
    group = {i}  # Initialize the group with the current index
    for j, model_j in enumerate(df['laptop_model_number_temp']):
        if i != j and (model_i in model_j or model_j in model_i):
            group.add(j)
    visited.update(group)
    groups[f"group_{len(groups) + 1}"] = list(group)

# Step 3: Map groups back to the DataFrame
df['group'] = None
for group_name, indices in groups.items():
    df.loc[indices, 'group'] = group_name

# View the DataFrame with groups
df.head(5)
# Out:
#     brand           laptop_model_name laptop_model_number processor_brand  \
# 0     TPV                     AceBook      AceBook_Silver           Intel
# 1      HP                   Elitebook             660 G11           Intel
# 2      HP                   HP Laptop                  HP           Intel
# 3  Lenovo  Ideapad 1 15" - 82R400EMUS          82R400EMUS             AMD
# 4    ASUS                   Strix G16         G614JV-AS74           Intel
#
#   processor_model storage_type operating_system  display_resolution  \
# 0         Core i5          SSD   Windows 11 Pro  1920 x 1080 Pixels
# 1         Core i7          SSD   Windows 11 Pro  1920 x 1200 Pixels
# 2       Celeron N          SSD  Windows 11 Home   1366 x 768 Pixels
# 3         Ryzen 5          SSD  Windows 11 Home    1920x1080 Pixels
# 4         Core i7          SSD  Windows 11 Home   1366 x 768 pixels
#
#    extracted_rating  battery_life_hours_upto    price  stock  \
# 0               4.4                      5.0   309.99   True
# 1               5.0                      NaN  1089.00   True
# 2               4.1                     11.0   265.99   True
# 3               4.4                     10.0   379.00   True
# 4               4.3                      NaN  1267.46   True
#
#     time_of_extraction  \
# 0  2024-12-05 12:15:37
# 1  2024-12-05 12:15:41
# 2  2024-12-05 12:15:53
# 3  2024-12-05 12:15:57
# 4  2024-12-05 12:16:21
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       url  \
# 0  https://www.amazon.com/sspa/click?ie=UTF8&spc=MToyNTU2ODExODc2NTY2MDA3OjE3MjY5OTc5MTM6c3BfYXRmX2Jyb3dzZTozMDAzMzE1MDUzNjc5MDI6OjA6Og&url=%2FTPV-Computer-Display-Windows-Notebook%2Fdp%2FB0D87RK5Q8%2Fref%3Dsr_1_2_sspa%3Fdib%3DeyJ2IjoiMSJ9.Mxv-LfaT1mRTkqi6GWEFXxFggO64cMc5a5WQAxAoDYKDc12AZYR8P_ulvGvs2fWDJ7_Nm3Q_vhpmjYCsv0OJPJs6Bo1FRX66cFxFfjDS5M6on
2yyijUubD6xTB3G5UxB2MqPQQaHrdLyLai29xSPy1hZkKf5Sm2MjOm9tSgk53w2mGq_T8vokhTRQYuN1uCwbBymaj5IEXp_6tzKZ-DZ8lOcjCmWHFWVn2fkST3y58q3_y3AxTbeKQumI-hyzZmMa7tonKGyaYVia00.eFMZpiqa4BbfF8ul13G1oFWFR-jOJGFy_-1DtQHxgmY&dib_tag=se&qid=1726997913&s=pc&sr=1-7
# 4                                                                                                                                                                                                                             https://www.amazon.com/ASUS-ROG-Strix-Gaming-Laptop/dp/B0CRDCXRK2/ref=sr_1_8?dib=eyJ2IjoiMSJ9.Mxv-LfaT1mRTkqi6GWEFXxFggO64cMc5a5WQAxAoDYKDc12AZYR8P_ulvGvs2fWDJ7_Nm3Q_vhpmjYCsv0OJPJs6Bo1FRX66cFxFfjDS5M6onhimzcAeCOZ3ganbR1ztxCB3tNO3H2yyijUubD6xTB3G5UxB2MqPQQaHrdLyLai29xSPy1hZkKf5Sm2MjOm9tSgk53w2mGq_T8vokhTRQYuN1uCwbBymaj5IEXp_6tzKZ-DZ8lOcjCmWHFWVn2fkST3y58q3_y3AxTbeKQumI-hyzZmMa7tonKGyaYVia00.eFMZpiqa4BbfF8ul13G1oFWFR-jOJGFy_-1DtQHxgmY&dib_tag=se&qid=1726997913&s=pc&sr=1-8
#
#    source  storage_capacity_gb  display_size_inches  ram_gb no_of_reviews  \
# 0  Amazon                  512                 15.6      16            52
# 1  Amazon                 2048                 16.0      32             6
# 2  Amazon                   64                 14.0       8           878
# 3  Amazon                  512                 15.6       8           639
# 4  Amazon                 2048                 16.0      16           473
#
#              laptop_dimensions  laptop_weight_pounds  \
# 0   14.09 x 8.97 x 0.86 inches                  3.63
# 1   14.14 x 9.20 x 0.78 inches                  3.85
# 2   8.86 x 12.76 x 0.71 inches                  3.24
# 3   9.29 x 14.17 x 0.70 inches                  3.52
# 4  13.94 x 0.89 x 10.39 inches                  5.51
#
#                                                                            image_src  \
# 0  https://m.media-amazon.com/images/I/818cXcaog9L.__AC_SX300_SY300_QL70_FMwebp_.jpg
# 1  https://m.media-amazon.com/images/I/71nSy8Uh8iL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# 2  https://m.media-amazon.com/images/I/81divYKpeTL.__AC_SY300_SX300_QL70_FMwebp_.jpg
# 3  https://m.media-amazon.com/images/I/51h3oOo7XnL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# 4  https://m.media-amazon.com/images/I/81GrCeuCzxL.__AC_SY300_SX300_QL70_FMwebp_.jpg
#
#                                                                                                                                                                                                 title  \
# 0           TPV 15.6" Laptop Computer (Intel Core i5 / 16GB RAM/ 512GB SSD), MS Office 2024, FHD Display with 100% sRGB Color Gamut, Windows 11 Pro Notebook PC with Dual Band Wi-Fi, Webcam (Silver)
# 1  HP Elitebook 660 G11 16" FHD+ Business AI Laptop Computer, Intel Ultra 7 155U (Beat i7-1355U), 32GB DDR5 RAM, 1TB PCIe SSD, WiFi 6E, Backlit Keyboard, Fingerprint Reader, Windows 11 Pro Vent-HEA
# 2                              HP 14" Ultral Light Laptop for Students and Business, Intel Quad-Core, 8GB RAM, 192GB Storage(64GB eMMC+128GB Ghost Manta SD Card), 1 Year Office 365, USB C, Win 11 S
# 3                               Lenovo IdeaPad 1 Laptop, 15.6” FHD Display, AMD Ryzen 5 5500U, 8GB RAM, 512GB SSD, Windows 11 Home, 720p Camera w/Privacy Shutter, Smart Noise Cancelling, Cloud Grey
# 4             ASUS ROG Strix G16 (2024) Gaming Laptop, 16” 16:10 FHD 165Hz Display, NVIDIA® GeForce RTX™ 4060, Intel Core i7-13650HX, 16GB DDR5, 1TB PCIe Gen4 SSD, Wi-Fi 6E, Windows 11, G614JV-AS74
#
#   laptop_model_number_temp    group
# 0           acebook_silver  group_1
# 1                  660 g11  group_2
# 2                       hp  group_3
# 3               82r400emus  group_4
# 4              g614jv-as74  group_5

# %%
len(groups.keys())
# Out:
# 1623

# %%
# Find the group with size 3
group_with_size_3 = group_sizes[group_sizes == 5]

if not group_with_size_3.empty:
    group_name = group_with_size_3.index[1]  # Get the name of the group
    group_size = group_with_size_3.iloc[1]   # Get the size of the group

    # Extract rows belonging to the group with size 3
    group_rows = df[df['group'] == group_name]

    # Output the results
    print(f"Group with size 3: {group_name}")
    print(f"Group size: {group_size}")
    print("Rows in the group with size 3:")
    print(group_rows)
else:
    print("No group has size 3.")
# Out:
# Group with size 3: group_129
# Group size: 5
# Rows in the group with size 3:
#        brand  \
# 222   Lenovo
# 1254  Lenovo
# 1505  Lenovo
# 2537  Lenovo
# 4299  Lenovo
#
#                                                              laptop_model_name  \
# 222                                                                       21JT
# 1254                                                        ThinkPad E16 Gen 1
# 1505                                                                      21JT
# 2537                                                        ThinkPad E16 Gen 1
# 4299  ThinkPad E16 Gen 1 16" Laptop - AMD Ryzen 5 with 16GB memory - 256GB SSD
#
#      laptop_model_number processor_brand processor_model storage_type  \
# 222                 21JT             AMD         Ryzen 5          SSD
# 1254          21JT001PUS             AMD         Ryzen 5          SSD
# 1505                21JT             AMD         Ryzen 5          SSD
# 2537          21JT001PUS             AMD         Ryzen 5          SSD
# 4299          21JT001BUS             AMD         Ryzen 5          SSD
#
#      operating_system   display_resolution  extracted_rating  \
# 222    Windows 11 Pro   1920 x 1200 Pixels               4.2
# 1254   Windows 11 Pro   1920 x 1200 Pixels               3.8
# 1505   Windows 11 Pro   1920 x 1200 Pixels               4.2
# 2537   Windows 11 Pro   1920 x 1200 Pixels               3.8
# 4299   Windows 11 Pro  1920 x 1200 (WUXGA)               5.0
#
#       battery_life_hours_upto   price  stock   time_of_extraction  \
# 222                       NaN  676.00   True  2024-12-05 12:36:49
# 1254                      NaN  598.00   True  2024-12-05 15:15:38
# 1505                      NaN  676.00   True  2024-12-05 12:36:49
# 2537                      NaN  598.00   True  2024-12-05 15:15:38
# 4299                      NaN  789.99   True  2024-12-05 04:21:19
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     url  \
# 222   https://www.amazon.com/Lenovo-ThinkPad-Business-i7-1165G7-Fingerprint/dp/B0CG2PZR8R/ref=sr_1_201?dib=eyJ2IjoiMSJ9.UNycNdVJ1BgLbHwhbCX-m5f7S3PjLSVb75E1hoSoNOAMdVEBiRnFyqF4-mLZxo8chp9EjX06UN0ZZmHTWiQU2vUJ9IYvilJgJ47hZ0WRy6Kf
# 4299                                                                                                                                                                                                                                                                                                                                                                              https://www.bestbuy.com/site/lenovo-thinkpad-e16-gen-1-16-laptop-amd-ryzen-5-with-16gb-memory-256gb-ssd-black/6559398.p?skuId=6559398
#
#        source  storage_capacity_gb  display_size_inches  ram_gb no_of_reviews  \
# 222    Amazon                 2048                 16.0      24           128
# 1254   Amazon                  256                 16.0       8             9
# 1505   Amazon                 2048                 16.0      24           128
# 2537   Amazon                  256                 16.0       8             9
# 4299  BestBuy                  256                 16.0      16   (2 Reviews)
#
#                laptop_dimensions  laptop_weight_pounds  \
# 222   14.01 x 9.75 x 0.77 inches                  3.99
# 1254  9.80 x 14.00 x 0.78 inches                  5.95
# 1505  14.01 x 9.75 x 0.77 inches                  3.99
# 2537  9.80 x 14.00 x 0.78 inches                  5.95
# 4299  0.78 x 14.02 x 9.75 inches                  4.34
#
#                                                                                                                       image_src  \
# 222                                                        https://m.media-amazon.com/images/I/712KStt+31L._AC_SY300_SX300_.jpg
# 1254                                          https://m.media-amazon.com/images/I/61zJnNmvGRL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# 1505                                                       https://m.media-amazon.com/images/I/712KStt+31L._AC_SY300_SX300_.jpg
# 2537                                          https://m.media-amazon.com/images/I/61zJnNmvGRL.__AC_SX300_SY300_QL70_FMwebp_.jpg
# 4299  https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6559/6559398_sd.jpg;maxHeight=640;maxWidth=550;format=webp
#
#                                                                                                                                                                                             title  \
# 222   Lenovo ThinkPad E16 Business Laptop, 16" WUXGA Display, AMD Ryzen 5 7530U (Beat i7-1165G7), 24GB RAM, 1TB PCIe SSD, Webcam, HDMI, RJ-45, Fingerprint Reader, Wi-Fi 6, Windows 11 Pro, Black
# 1254   Lenovo ThinkPad E16 Gen 1 21JT001PUS 16" Notebook - WUXGA - 1920 x 1200 - AMD Ryzen 5 7530U Hexa-core (6 Core) 2 GHz - 8 GB Total RAM - 8 GB On-Board Memory - 256 GB SSD - Graphite Black
# 1505  Lenovo ThinkPad E16 Business Laptop, 16" WUXGA Display, AMD Ryzen 5 7530U (Beat i7-1165G7), 24GB RAM, 1TB PCIe SSD, Webcam, HDMI, RJ-45, Fingerprint Reader, Wi-Fi 6, Windows 11 Pro, Black
# 2537   Lenovo ThinkPad E16 Gen 1 21JT001PUS 16" Notebook - WUXGA - 1920 x 1200 - AMD Ryzen 5 7530U Hexa-core (6 Core) 2 GHz - 8 GB Total RAM - 8 GB On-Board Memory - 256 GB SSD - Graphite Black
# 4299                                                                                                    Lenovo - ThinkPad E16 Gen 1 16" Laptop - AMD Ryzen 5 with 16GB memory - 256GB SSD - Black
#
#      laptop_model_number_temp      group
# 222                      21jt  group_129
# 1254               21jt001pus  group_129
# 1505                     21jt  group_129
# 2537               21jt001pus  group_129
# 4299               21jt001bus  group_129

# %%
displacy.render(nlp(df.iloc[164]['title']),style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dell Chromebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  11 3100
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11.6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# &quot;
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Touchscreen 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chromebook - HD - 1366
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  x
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     768
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  - Intel
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Celeron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  N4020
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dual-Core
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (2 Core) - 4
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GB RAM -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     32
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flash Memory (Renewed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# )</div></span>
